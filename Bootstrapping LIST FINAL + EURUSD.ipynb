# %%
import numpy as np
import xlwings as xw
import pandas as pd
from datetime import datetime

# %%
# PARAMETERS

# As of date
date = '22.09.2021'

# Number of simulations
Nsims = 1000000

# Confidence level
prc = 99.9

# %%
# UPLOAD DATA

wb = xw.Book('M:/SHARE/Risk_Invest/Рыночные риски/7.Бэктест VaR/VaR OCP+ES_v3.xlsx')
sh = wb.sheets[0]

for cell in range (5, 5000):
    if pd.to_datetime(sh.range('A' + str(cell)).value) == pd.to_datetime(date, format='%d.%m.%Y'):
        break

last_row = cell
first_row = last_row - 513
rngUSD = 'H' + str(first_row) + ':' + 'H' + str(last_row)
dataUSD = sh.range(rngUSD).value
rngEUR = 'G' + str(first_row) + ':' + 'G' + str(last_row)
dataEUR = sh.range(rngEUR).value
dataEURUSD = np.array(sh.range(rngEUR).value) - np.array(sh.range(rngUSD).value)

# %%
# CALCULATION

simulatedUSD4 = []
simulatedUSD8 = []
simulatedUSD13 = []
simulatedUSD23 = []
simulatedUSD43 = []
simulatedUSD63 = []
simulatedUSD83 = []
simulatedUSD128 = []
simulatedUSD151 = []
simulatedUSD193 = []
simulatedUSD258 = []

simulatedEUR4 = []
simulatedEUR8 = []
simulatedEUR13 = []
simulatedEUR23 = []
simulatedEUR43 = []
simulatedEUR63 = []
simulatedEUR83 = []
simulatedEUR128 = []
simulatedEUR151 = []
simulatedEUR193 = []
simulatedEUR258 = []

simulatedEURUSD4 = []
simulatedEURUSD8 = []
simulatedEURUSD13 = []
simulatedEURUSD23 = []
simulatedEURUSD43 = []
simulatedEURUSD63 = []
simulatedEURUSD83 = []
simulatedEURUSD128 = []
simulatedEURUSD151 = []
simulatedEURUSD193 = []
simulatedEURUSD258 = []


for i in range(Nsims):
    array_expUSD = np.exp(np.random.choice(dataUSD, size = 260))
    
    simulatedUSD4.append(np.prod(array_expUSD[:4]) - 1)
    simulatedUSD8.append(np.prod(array_expUSD[:8]) - 1)
    simulatedUSD13.append(np.prod(array_expUSD[:13]) - 1)
    simulatedUSD23.append(np.prod(array_expUSD[:23]) - 1)
    simulatedUSD43.append(np.prod(array_expUSD[:43]) - 1)
    simulatedUSD63.append(np.prod(array_expUSD[:63]) - 1)
    simulatedUSD83.append(np.prod(array_expUSD[:83]) - 1)
    simulatedUSD128.append(np.prod(array_expUSD[:128]) - 1)
    simulatedUSD151.append(np.prod(array_expUSD[:151]) - 1)
    simulatedUSD193.append(np.prod(array_expUSD[:193]) - 1)
    simulatedUSD258.append(np.prod(array_expUSD[:258]) - 1)
    
for j in range(Nsims):
    array_expEUR = np.exp(np.random.choice(dataEUR, size = 260))
    
    simulatedEUR4.append(np.prod(array_expEUR[:4]) - 1)
    simulatedEUR8.append(np.prod(array_expEUR[:8]) - 1)
    simulatedEUR13.append(np.prod(array_expEUR[:13]) - 1)
    simulatedEUR23.append(np.prod(array_expEUR[:23]) - 1)
    simulatedEUR43.append(np.prod(array_expEUR[:43]) - 1)
    simulatedEUR63.append(np.prod(array_expEUR[:63]) - 1)
    simulatedEUR83.append(np.prod(array_expEUR[:83]) - 1)
    simulatedEUR128.append(np.prod(array_expEUR[:128]) - 1)
    simulatedEUR151.append(np.prod(array_expEUR[:151]) - 1)
    simulatedEUR193.append(np.prod(array_expEUR[:193]) - 1)
    simulatedEUR258.append(np.prod(array_expEUR[:258]) - 1)    

for j in range(Nsims):
    array_expEURUSD = np.exp(np.random.choice(dataEURUSD, size = 260))
    
    simulatedEURUSD4.append(np.prod(array_expEURUSD[:4]) - 1)
    simulatedEURUSD8.append(np.prod(array_expEURUSD[:8]) - 1)
    simulatedEURUSD13.append(np.prod(array_expEURUSD[:13]) - 1)
    simulatedEURUSD23.append(np.prod(array_expEURUSD[:23]) - 1)
    simulatedEURUSD43.append(np.prod(array_expEURUSD[:43]) - 1)
    simulatedEURUSD63.append(np.prod(array_expEURUSD[:63]) - 1)
    simulatedEURUSD83.append(np.prod(array_expEURUSD[:83]) - 1)
    simulatedEURUSD128.append(np.prod(array_expEURUSD[:128]) - 1)
    simulatedEURUSD151.append(np.prod(array_expEURUSD[:151]) - 1)
    simulatedEURUSD193.append(np.prod(array_expEURUSD[:193]) - 1)
    simulatedEURUSD258.append(np.prod(array_expEURUSD[:258]) - 1)        


simulatedUSD4 = np.array(simulatedUSD4)
simulatedUSD8 = np.array(simulatedUSD8)
simulatedUSD13 = np.array(simulatedUSD13)
simulatedUSD23 = np.array(simulatedUSD23)
simulatedUSD43 = np.array(simulatedUSD43)
simulatedUSD63 = np.array(simulatedUSD63)
simulatedUSD83 = np.array(simulatedUSD83)
simulatedUSD128 = np.array(simulatedUSD128)
simulatedUSD151 = np.array(simulatedUSD151)
simulatedUSD193 = np.array(simulatedUSD193)
simulatedUSD258 = np.array(simulatedUSD258)

simulatedEUR4 = np.array(simulatedEUR4)
simulatedEUR8 = np.array(simulatedEUR8)
simulatedEUR13 = np.array(simulatedEUR13)
simulatedEUR23 = np.array(simulatedEUR23)
simulatedEUR43 = np.array(simulatedEUR43)
simulatedEUR63 = np.array(simulatedEUR63)
simulatedEUR83 = np.array(simulatedEUR83)
simulatedEUR128 = np.array(simulatedEUR128)
simulatedEUR151 = np.array(simulatedEUR151)
simulatedEUR193 = np.array(simulatedEUR193)
simulatedEUR258 = np.array(simulatedEUR258)

simulatedEURUSD4 = np.array(simulatedEURUSD4)
simulatedEURUSD8 = np.array(simulatedEURUSD8)
simulatedEURUSD13 = np.array(simulatedEURUSD13)
simulatedEURUSD23 = np.array(simulatedEURUSD23)
simulatedEURUSD43 = np.array(simulatedEURUSD43)
simulatedEURUSD63 = np.array(simulatedEURUSD63)
simulatedEURUSD83 = np.array(simulatedEURUSD83)
simulatedEURUSD128 = np.array(simulatedEURUSD128)
simulatedEURUSD151 = np.array(simulatedEURUSD151)
simulatedEURUSD193 = np.array(simulatedEURUSD193)
simulatedEURUSD258 = np.array(simulatedEURUSD258)
    
VaR_USD4 = np.percentile(simulatedUSD4, prc, interpolation = 'linear')
VaR_USD8 = np.percentile(simulatedUSD8, prc, interpolation = 'linear')
VaR_USD13 = np.percentile(simulatedUSD13, prc, interpolation = 'linear')
VaR_USD23 = np.percentile(simulatedUSD23, prc, interpolation = 'linear')
VaR_USD43 = np.percentile(simulatedUSD43, prc, interpolation = 'linear')
VaR_USD63 = np.percentile(simulatedUSD63, prc, interpolation = 'linear')
VaR_USD83 = np.percentile(simulatedUSD83, prc, interpolation = 'linear')
VaR_USD128 = np.percentile(simulatedUSD128, prc, interpolation = 'linear')
VaR_USD151 = np.percentile(simulatedUSD151, prc, interpolation = 'linear')
VaR_USD193 = np.percentile(simulatedUSD193, prc, interpolation = 'linear')
VaR_USD258 = np.percentile(simulatedUSD258, prc, interpolation = 'linear')

VaR_EUR4 = np.percentile(simulatedEUR4, prc, interpolation = 'linear')
VaR_EUR8 = np.percentile(simulatedEUR8, prc, interpolation = 'linear')
VaR_EUR13 = np.percentile(simulatedEUR13, prc, interpolation = 'linear')
VaR_EUR23 = np.percentile(simulatedEUR23, prc, interpolation = 'linear')
VaR_EUR43 = np.percentile(simulatedEUR43, prc, interpolation = 'linear')
VaR_EUR63 = np.percentile(simulatedEUR63, prc, interpolation = 'linear')
VaR_EUR83 = np.percentile(simulatedEUR83, prc, interpolation = 'linear')
VaR_EUR128 = np.percentile(simulatedEUR128, prc, interpolation = 'linear')
VaR_EUR151 = np.percentile(simulatedEUR151, prc, interpolation = 'linear')
VaR_EUR193 = np.percentile(simulatedEUR193, prc, interpolation = 'linear')
VaR_EUR258 = np.percentile(simulatedEUR258, prc, interpolation = 'linear')

VaR_EURUSD4 = np.percentile(simulatedEURUSD4, prc, interpolation = 'linear')
VaR_EURUSD8 = np.percentile(simulatedEURUSD8, prc, interpolation = 'linear')
VaR_EURUSD13 = np.percentile(simulatedEURUSD13, prc, interpolation = 'linear')
VaR_EURUSD23 = np.percentile(simulatedEURUSD23, prc, interpolation = 'linear')
VaR_EURUSD43 = np.percentile(simulatedEURUSD43, prc, interpolation = 'linear')
VaR_EURUSD63 = np.percentile(simulatedEURUSD63, prc, interpolation = 'linear')
VaR_EURUSD83 = np.percentile(simulatedEURUSD83, prc, interpolation = 'linear')
VaR_EURUSD128 = np.percentile(simulatedEURUSD128, prc, interpolation = 'linear')
VaR_EURUSD151 = np.percentile(simulatedEURUSD151, prc, interpolation = 'linear')
VaR_EURUSD193 = np.percentile(simulatedEURUSD193, prc, interpolation = 'linear')
VaR_EURUSD258 = np.percentile(simulatedEURUSD258, prc, interpolation = 'linear')

ES_USD1 = np.max(np.exp(dataUSD)) - 1
ES_USD4 = np.mean(simulatedUSD4[simulatedUSD4 > VaR_USD4])
ES_USD8 = np.mean(simulatedUSD8[simulatedUSD8 > VaR_USD8])
ES_USD13 = np.mean(simulatedUSD13[simulatedUSD13 > VaR_USD13])
ES_USD23 = np.mean(simulatedUSD23[simulatedUSD23 > VaR_USD23])
ES_USD43 = np.mean(simulatedUSD43[simulatedUSD43 > VaR_USD43])
ES_USD63 = np.mean(simulatedUSD63[simulatedUSD63 > VaR_USD63])
ES_USD83 = np.mean(simulatedUSD83[simulatedUSD83 > VaR_USD83])
ES_USD128 = np.mean(simulatedUSD128[simulatedUSD128 > VaR_USD128])
ES_USD151 = np.mean(simulatedUSD151[simulatedUSD151 > VaR_USD151])
ES_USD193 = np.mean(simulatedUSD193[simulatedUSD193 > VaR_USD193])
ES_USD258 = np.mean(simulatedUSD258[simulatedUSD258 > VaR_USD258])

ES_EUR1 = np.max(np.exp(dataEUR)) - 1
ES_EUR4 = np.mean(simulatedEUR4[simulatedEUR4 > VaR_EUR4])
ES_EUR8 = np.mean(simulatedEUR8[simulatedEUR8 > VaR_EUR8])
ES_EUR13 = np.mean(simulatedEUR13[simulatedEUR13 > VaR_EUR13])
ES_EUR23 = np.mean(simulatedEUR23[simulatedEUR23 > VaR_EUR23])
ES_EUR43 = np.mean(simulatedEUR43[simulatedEUR43 > VaR_EUR43])
ES_EUR63 = np.mean(simulatedEUR63[simulatedEUR63 > VaR_EUR63])
ES_EUR83 = np.mean(simulatedEUR83[simulatedEUR83 > VaR_EUR83])
ES_EUR128 = np.mean(simulatedEUR128[simulatedEUR128 > VaR_EUR128])
ES_EUR151 = np.mean(simulatedEUR151[simulatedEUR151 > VaR_EUR151])
ES_EUR193 = np.mean(simulatedEUR193[simulatedEUR193 > VaR_EUR193])
ES_EUR258 = np.mean(simulatedEUR258[simulatedEUR258 > VaR_EUR258])

ES_EURUSD1 = np.max(np.exp(dataEURUSD)) - 1
ES_EURUSD4 = np.mean(simulatedEURUSD4[simulatedEURUSD4 > VaR_EURUSD4])
ES_EURUSD8 = np.mean(simulatedEURUSD8[simulatedEURUSD8 > VaR_EURUSD8])
ES_EURUSD13 = np.mean(simulatedEURUSD13[simulatedEURUSD13 > VaR_EURUSD13])
ES_EURUSD23 = np.mean(simulatedEURUSD23[simulatedEURUSD23 > VaR_EURUSD23])
ES_EURUSD43 = np.mean(simulatedEURUSD43[simulatedEURUSD43 > VaR_EURUSD43])
ES_EURUSD63 = np.mean(simulatedEURUSD63[simulatedEURUSD63 > VaR_EURUSD63])
ES_EURUSD83 = np.mean(simulatedEURUSD83[simulatedEURUSD83 > VaR_EURUSD83])
ES_EURUSD128 = np.mean(simulatedEURUSD128[simulatedEURUSD128 > VaR_EURUSD128])
ES_EURUSD151 = np.mean(simulatedEURUSD151[simulatedEURUSD151 > VaR_EURUSD151])
ES_EURUSD193 = np.mean(simulatedEURUSD193[simulatedEURUSD193 > VaR_EURUSD193])
ES_EURUSD258 = np.mean(simulatedEURUSD258[simulatedEURUSD258 > VaR_EURUSD258])

results = pd.DataFrame([[ES_USD1, ES_EUR1, ES_EURUSD1], [ES_USD4, ES_EUR4, ES_EURUSD4], [ES_USD8, ES_EUR8, ES_EURUSD8], 
                        [ES_USD13, ES_EUR13, ES_EURUSD13], [ES_USD23, ES_EUR23, ES_EURUSD23], 
                        [ES_USD43, ES_EUR43, ES_EURUSD43], [ES_USD63, ES_EUR63, ES_EURUSD63], 
                        [ES_USD83, ES_EUR83, ES_EURUSD83], [ES_USD128, ES_EUR128, ES_EURUSD128], 
                        [ES_USD151, ES_EUR151, ES_EURUSD151], [ES_USD193, ES_EUR193, ES_EURUSD193], 
                        [ES_USD258, ES_EUR258, ES_EURUSD258]])
results.columns = ['USD', 'EUR', 'EURUSD']
results.head(15)
# Out:
#          USD       EUR    EURUSD
# 0   0.072052  0.063825  0.014044
# 1   0.099676  0.092314  0.028260
# 2   0.125517  0.118268  0.039989
# 3   0.151175  0.144312  0.051604
# 4   0.190580  0.185317  0.069779
# 5   0.253953  0.253312  0.098489
# 6   0.307478  0.309714  0.122246
# 7   0.354810  0.364064  0.143486
# 8   0.455201  0.474744  0.184165
# 9   0.501952  0.527328  0.203672
# 10  0.584310  0.619594  0.236573
# 11  0.701749  0.756215  0.283978
