# %%
import pandas as pd
from scipy.stats import mannwhitneyu
from scipy.stats import spearmanr

# %%
data_ex = pd.read_excel('C:/Users/serst/Desktop/Результаты.xlsx', sheet_name = 2, index_col = None)
data_ex.head()
# Out:
#    ex_ind_em  ex_ind_pozn  ex_ind_prakt  ex_ind_postup  ex_ind_intens  \
# 0          5            3             5              3              4
# 1          3            2             4              4              3
# 2          5            4             8              5              6
# 3          6            3             3              3              3
# 4          8            8             7              8              8
#
#    ex_ei_opora  ex_ei_zasch  ex_ei_prostr  ex_ei_1fm  ex_ei_sootn  ...  \
# 0            8            7             7         22            5  ...
# 1           10            8             9         27            7  ...
# 2           11            7             9         27            8  ...
# 3           12           11            10         33           10  ...
# 4           11            8             7         26           12  ...
#
#    ex_ei_cenvb  ex_ei_4fm  ex_ei_ei  ex_vkz_subocz  ex_vkz_cenz  \
# ...

# %%
ex_ind_em = list(data_ex.iloc[:, 0])
ex_ind_em
# Out:
# [5,
#  3,
#  5,
#  6,
#  8,
#  5,
#  3,
#  4,
#  1,
#  5,
#  7,
#  2,
#  5,
#  3,
#  5,
#  4,
#  5,
#  8,
#  3,
#  3,
#  3,
#  4,
#  6,
#  8,
#  5,
#  5,
#  4,
#  2,
#  3,
#  7,
#  5,
#  1,
#  7,
#  6,
#  2,
#  5,
#  5,
#  5,
#  6,
#  4,
#  3,
#  7,
#  5,
#  8,
#  3,
#  8,
#  7,
#  5,
#  3,
#  5,
#  6,
#  5,
#  7,
#  3,
#  7,
#  6]

# %%
variables_ex = list(data_ex.columns.values)
variables_ex
# Out:
# ['ex_ind_em',
#  'ex_ind_pozn',
#  'ex_ind_prakt',
#  'ex_ind_postup',
#  'ex_ind_intens',
#  'ex_ei_opora',
#  'ex_ei_zasch',
#  'ex_ei_prostr',
#  'ex_ei_1fm',
#  'ex_ei_sootn',
#  'ex_ei_vremia',
#  'ex_ei_bliz',
#  'ex_ei_2fm',
#  'ex_ei_zvnim',
#  'ex_ei_sprot',
#  'ex_ei_prizc',
#  'ex_ei_3fm',
#  'ex_ei_vozmdd',
#  'ex_ei_vklvv',
#  'ex_ei_cenvb',
#  'ex_ei_4fm',
#  'ex_ei_ei',
#  'ex_vkz_subocz',
#  'ex_vkz_cenz',
#  'ex_vkz_osvipovk',
#  'ex_vkz_lokusk',
#  'ex_vkz_pozprog',
#  'ex_vkz_sum',
#  'ex_addict']

# %%
variables_list = data_ex.values.T.tolist()
ex_ind_em = variables_list[0]
ex_ind_em
# Out:
# 56

# %%
data_n_ex = pd.read_excel('C:/Users/serst/Desktop/Результаты.xlsx', sheet_name = 3, index_col = None)
data_n_ex.head()
# Out:
#    n_ex_ind_em  n_ex_ind_pozn  n_ex_ind_prakt  n_ex_ind_postup  \
# 0            3              4               3                5
# 1            3              6               5                6
# 2            3              3               3                2
# 3            1              4               5                5
# 4            5              8               6                8
#
#    n_ex_ind_intens  n_ex_ei_opora  n_ex_ei_zasch  n_ex_ei_prostr  n_ex_ei_1fm  \
# 0                4             12              5               9           26
# 1                5             11             11               7           29
# 2                2             12              4               6           22
# 3                4              9             10               5           24
# 4                7              5              8              11           24
#
#    n_ex_ei_sootn  ...  n_ex_ei_cenvb  n_ex_ei_4fm  n_ex_ei_ei  \
# ...

# %%
variables_n_ex = list(data_n_ex.columns.values)
variables_n_ex
# Out:
# ['n_ex_ind_em',
#  'n_ex_ind_pozn',
#  'n_ex_ind_prakt',
#  'n_ex_ind_postup',
#  'n_ex_ind_intens',
#  'n_ex_ei_opora',
#  'n_ex_ei_zasch',
#  'n_ex_ei_prostr',
#  'n_ex_ei_1fm',
#  'n_ex_ei_sootn',
#  'n_ex_ei_vremia',
#  'n_ex_ei_bliz',
#  'n_ex_ei_2fm',
#  'n_ex_ei_zvnim',
#  'n_ex_ei_sprot',
#  'n_ex_ei_prizc',
#  'n_ex_ei_3fm',
#  'n_ex_ei_vozmdd',
#  'n_ex_ei_vklvv',
#  'n_ex_ei_cenvb',
#  'n_ex_ei_4fm',
#  'n_ex_ei_ei',
#  'n_ex_vkz_subocz',
#  'n_ex_vkz_cenz',
#  'n_ex_vkz_osvipovk',
#  'n_ex_vkz_lokusk',
#  'n_ex_vkz_pozprog',
#  'n_ex_vkz_sum',
#  'n_ex_addict']
