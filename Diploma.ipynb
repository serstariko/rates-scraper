# %%
import pandas as pd
import numpy as np
from scipy.stats import mannwhitneyu
from scipy.stats import spearmanr

# %%
ex_ind_em = list(data_ex.iloc[:, 0])
ex_ind_pozn = list(data_ex.iloc[:, 1])
ex_ind_prakt = list(data_ex.iloc[:, 2])
ex_ind_postup = list(data_ex.iloc[:, 3])
ex_ind_intens = list(data_ex.iloc[:, 4])
ex_ei_opora = list(data_ex.iloc[:, 5])
ex_ei_zasch = list(data_ex.iloc[:, 6])
ex_ei_prostr = list(data_ex.iloc[:, 7])
ex_ei_1fm = list(data_ex.iloc[:, 8])
ex_ei_sootn = list(data_ex.iloc[:, 9])
ex_ei_vremia = list(data_ex.iloc[:, 10])
ex_ei_bliz = list(data_ex.iloc[:, 11])
ex_ei_2fm = list(data_ex.iloc[:, 12])
ex_ei_zvnim = list(data_ex.iloc[:, 13])
ex_ei_sprot = list(data_ex.iloc[:, 14])
ex_ei_prizc = list(data_ex.iloc[:, 15])
ex_ei_3fm = list(data_ex.iloc[:, 16])
ex_ei_vozmdd = list(data_ex.iloc[:, 17])
ex_ei_vklvv = list(data_ex.iloc[:, 18])
ex_ei_cenvb = list(data_ex.iloc[:, 19])
ex_ei_4fm = list(data_ex.iloc[:, 20])
ex_ei_ei = list(data_ex.iloc[:, 21])
ex_vkz_subocz = list(data_ex.iloc[:, 22])
ex_vkz_cenz = list(data_ex.iloc[:, 23])
ex_vkz_osvipovk = list(data_ex.iloc[:, 24])
ex_vkz_lokusk = list(data_ex.iloc[:, 25])
ex_vkz_pozprog = list(data_ex.iloc[:, 26])
ex_vkz_sum = list(data_ex.iloc[:, 27])
ex_addict = list(data_ex.iloc[:, 28])



n_ex_ind_em = list(data_n_ex.iloc[:, 0])
n_ex_ind_pozn = list(data_n_ex.iloc[:, 1])
n_ex_ind_prakt = list(data_n_ex.iloc[:, 2])
n_ex_ind_postup = list(data_n_ex.iloc[:, 3])
n_ex_ind_intens = list(data_n_ex.iloc[:, 4])
n_ex_ei_opora = list(data_n_ex.iloc[:, 5])
n_ex_ei_zasch = list(data_n_ex.iloc[:, 6])
n_ex_ei_prostr = list(data_n_ex.iloc[:, 7])
n_ex_ei_1fm = list(data_n_ex.iloc[:, 8])
n_ex_ei_sootn = list(data_n_ex.iloc[:, 9])
n_ex_ei_vremia = list(data_n_ex.iloc[:, 10])
n_ex_ei_bliz = list(data_n_ex.iloc[:, 11])
n_ex_ei_2fm = list(data_n_ex.iloc[:, 12])
n_ex_ei_zvnim = list(data_n_ex.iloc[:, 13])
n_ex_ei_sprot = list(data_n_ex.iloc[:, 14])
n_ex_ei_prizc = list(data_n_ex.iloc[:, 15])
n_ex_ei_3fm = list(data_n_ex.iloc[:, 16])
n_ex_ei_vozmdd = list(data_n_ex.iloc[:, 17])
n_ex_ei_vklvv = list(data_n_ex.iloc[:, 18])
n_ex_ei_cenvb = list(data_n_ex.iloc[:, 19])
n_ex_ei_4fm = list(data_n_ex.iloc[:, 20])
n_ex_ei_ei = list(data_n_ex.iloc[:, 21])
n_ex_vkz_subocz = list(data_n_ex.iloc[:, 22])
n_ex_vkz_cenz = list(data_n_ex.iloc[:, 23])
n_ex_vkz_osvipovk = list(data_n_ex.iloc[:, 24])
n_ex_vkz_lokusk = list(data_n_ex.iloc[:, 25])
n_ex_vkz_pozprog = list(data_n_ex.iloc[:, 26])
n_ex_vkz_sum = list(data_n_ex.iloc[:, 27])
n_ex_addict = list(data_n_ex.iloc[:, 28])
